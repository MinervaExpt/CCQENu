# %%
import os,sys
from ROOT import TFile,TNamed, TH1D, TCanvas, TMatrixDSym, TVectorD
from PlotUtils import MnvH1D, MnvH2D, MnvPlotter
import commentjson
from MatrixUtils import *
print ("got here")
# Out:
# Welcome to JupyROOT 6.28/12
# got here

# %%
DEBUG = 1

# %%
#include <sstream>

# code to split on any delimiter thanks to stackoverflow
#
# # split (s, delimiter) 
#   size_t pos_start = 0, pos_end, delim_len = delimiter.length()
#   token
#   # res
#
#   while ((pos_end = s.find (delimiter, pos_start)) not = std.string.npos) 
#     token = s.substr (pos_start, pos_end - pos_start)
#     pos_start = pos_end + delim_len
#     res.append (token)
#   
#
#   res.append (s.substr (pos_start))
#   return res
# 

# Main  - this will do set up, loop over events and then make some plots

def checktag(keys, tag) :
    count = 0
    for x in keys:
        if tag in x: count += 1
    return count
    #return std.count(keys.begin(), keys.end(), tag) > 0

# %%
def addentry(thing,one,two,three,four,value):
    ''' add entries to a dictionary 4 deep '''
    
    if thing == {}:
        thing[one] = {}
    if one not in thing:
        thing[one] = {}
    if thing[one] == {}:
        thing[one][two] = {}
    if two not in thing[one]:
        thing[one][two] = {}
    if thing[one][two] == {}:
        thing[one][two][three] = {}
    if three not in thing[one][two]:
        thing[one][two][three] = {}
    if thing[one][two][three] == {}:
        thing[one][two][three][four] = value
    if four not in thing[one][two][three]:
        thing[one][two][three][four] = value

    #print ("added",thing[one][two][three],one,two,three,four)

# %%
print ("starting main")
# mainlen(sys.sys.argv), char* sys.argv[]) 
#gROOT.ProcessLine("gErrorIgnoreLevel = kWarning")
#++++++++++++++++++=  Initialization +++++++++++++++++++++++++

targets = 3.23478E30  # nucleons - is this the same for MC or different

inputtag = ""
if (len(sys.argv) > 1): 
    inputtag = (sys.argv[1])
else: 
    print(" arguments are:\n analyze <config>_<prescale> [sample] or <inputFile.root> [sample]" )
    inputtag = "/Users/schellma/Dropbox/FORGE/CCQENu/make_hists/BDT_3.root"
    #sys.exit(0)
    
    # NuConfig config
    # TFile* f
    # inputname
    # configloc
    # singlesample
    # asample = ""
    # hasbkgsub
    # usetune

    #------------get and store the configs from root or disk

allconfigs = {}


configloc = "root"
inputname = "/Users/schellma/Dropbox/FORGE/CCQENu/make_hists/BDT_3_out.root"
# if len(sys.argv) > 1: 
#     print("getting config from root input " , sys.argv[1] )
#     inputname = (sys.argv[1])
# else:
#     inputname = "/Users/schellma/Dropbox/ccqe/BDT2/samples.root"
usetune = False
f = TFile.Open(inputname, "READONLY")
g = TFile.Open(inputname.replace(".root","_out.root"),"RECREATE")

mains = f.Get("main").GetTitle()

#print (mains)
allconfigs["main"] = commentjson.loads(mains)
allconfigs["varsFile"] = commentjson.loads((f.Get("varsFile").GetTitle()))
allconfigs["cutsFile"] = commentjson.loads((f.Get("cutsFile").GetTitle()))
allconfigs["samplesFile"] = commentjson.loads((f.Get("samplesFile").GetTitle()))
allconfigs["Fit"] = commentjson.loads((f.Get("Fit").GetTitle()))
#print(allconfigs)

categoryMap = {}
count = 0
for x in allconfigs["Fit"]["Categories"]:
    categoryMap[x] = count
    count += 1

print (categoryMap)

singlesample = False
# see if the root file has already had fits done - these will be used in the cross section fit.
hasbkgsub = f.Get("fitconfig") != 0

if (len(sys.argv) > 2): 
    usetune = (sys.argv[2])

print ("read in config")
# Out:
# starting main
# {'qelike': 0, '1chargedpion': 1, '1neutralpion': 2, 'multipion': 3, 'other': 4}
# read in config

# %%
if (not singlesample): 
    SampleRequest = allconfigs["main"]["runsamples"]
print (SampleRequest)
playlist = allconfigs["main"]["playlist"]

m_fluxUniverses = allconfigs["main"]["fluxUniverses"]

print (playlist)
# Out:
# ['1track']
# minervame1N

# %%
#========================================= now get the histograms

# MnvH1D h_flux_dewidthed = GetFlux(allconfigs)

# flux = h_flux_dewidthed.Integral()
# # make containers for different analysis levels
# std.map<std.string, MnvH1D> h_flux_ebins

# now loop over histograms, unsmear, efficiency correct and normalize

# unfolding setup
#MinervaUnfold.MnvUnfold unfold
# MnvH2D MigrationMatrix
num_iter = 5

# input 4 D hist-map

# arguments will be sample, variable, thethetype, category
# order in histogram name is sample___category___variable___thetype
# thetype is reconstructed, truth...
# category is qelike, qelikenot ...



# std.map<std.string, std.map<std.string, std.map<std.string, std.map<std.string, MnvH2D> > > > hists2D

# std.map<std.string, std.map<std.string, std.map<std.string, std.map<std.string, MnvH2D> > > > response1D

# std.map<std.string, std.map<std.string, std.map<std.string, std.map<std.string, MnvH2D> > > > response2D

# f.ls()

# keys



# this is the old read in the POT.  They are also in a vector which Amit like having
h_pot = TH1D()
h_pot = f.Get("POT_summary")
h_pot.Print("ALL")

dataPOT = h_pot.GetBinContent(1)
mcPOTprescaled = h_pot.GetBinContent(3)
POTScale = dataPOT / mcPOTprescaled

norm = 1. / dataPOT / targets
targetobj = TNamed("targets", "%6e"%targets)

print(" integrated luminosity is " , 1 / norm / 1.E24 , "barns^-1" )

print(" POT MC " , mcPOTprescaled )
print(" POT DATA " , dataPOT )

print(" POT Scale",POTScale)
# Out:
#  integrated luminosity is  1.0422156217898972e+27 barns^-1
#  POT MC  1.5410047770696763e+21
#  POT DATA  3.2219057301884436e+20
#  POT Scale 0.20907824415152773
# TH1.Print Name  = POT_summary, Entries= 9, Total sum= 3.4042e+21
#  fSumw[0]=0, x=-0.5, error=0
#  fSumw[1]=3.22191e+20, x=0.5, error=1.86017e+20
#  fSumw[2]=1.541e+21, x=1.5, error=8.897e+20
#  fSumw[3]=1.541e+21, x=2.5, error=8.897e+20
#  fSumw[4]=0, x=3.5, error=0

# %%
hists1D={}
hists2D={}
response1D={}
response2D={}
parameters={}
covariance={}

null = MnvH1D("null", "empty histogram", 1, 0., 1.)
null2 = MnvH2D("null2", "empty histogram", 1, 0., 1., 1, 0., 1.)

samples = []
variables = []
categories = []
thetypes = []

# %%
count = 0
DEBUG=1
keys = []
keylist = open("keylist.txt",'w')
for k in f.GetListOfKeys():
    keylist.write(k.GetName()+"\n")
    #print(k)
    count += 1
    #if count > 400: break
    keys.append(k.GetName())
    key = k.GetName()

    parsekey = k.GetName().split("___")
    if len(parsekey) < 4: 
        #print(" not a " , k.GetName() )

        continue
    
    hNd = parsekey[0]
    sample = parsekey[1]
    category = parsekey[2]
    variable = parsekey[3]
    thetype = parsekey[4]
    
    # build lists of tags
    if not checktag(samples, sample):
        samples.append(sample)
        print(" add a sample: " , sample )

    if not checktag(categories, category): 
        categories.append(category)
        print(" add a category: " , category )
    
    if not checktag(variables, variable): 
        variables.append(variable)
        print(" add a variable: " , variable )
    
    if not checktag(thetypes, thetype):
        thetypes.append(thetype)
        print(" add a thetype: " , thetype )
    
    # get the histogram
    me = TNamed()
    me = f.GetKey(key)
    #print(" Done with parsing" )

    if "parameters" in key:
        hist = MnvH1D()
        hist = f.Get(key)
        addentry(parameters,sample,variable,thetype,category,hist.Clone())
        #parameters[sample][variable][thetype][category] = hist.Clone()
        print ("added parameters")
        parameters = ToVectorD(hist)
        parameters.Print()
        continue

    if "covariance" in key:
        hist = MnvH1D()
        hist = f.Get(key)
        addentry(covariance,sample,variable,thetype,category,hist.Clone())
        #parameters[sample][variable][thetype][category] = hist.Clone()
        print ("added Covariance")
        covariance = ToMatrixDSym(hist)
        covariance.Print()
        continue

    if "correlation" in key or ("h___" not in key[0:5] and "h2D___" not in key):
        continue

    # 1D hists
    if "h2D" in key:
        # if response in name its a 2D so do a cast to MnvH2D
        if key.find("migration"): 
            hist = MnvH2D()
            hist = (f.Get(key))
            if (hist != 0) and hist != None: 
                addentry(response1D,sample,variable,thetype,category,hist.Clone())
                #response1D[sample][variable][thetype][category].Scale(POTScale)
                # response1D[sample][variable][thetype][category].Print()
                response1D[sample][variable][thetype][category].SetDirectory(0)
                #print(" migration " , sample , " " , variable , " " , thetype , " " , category )
                #delete hist
            else: 
                #print("could not read " , key )
                response1D[sample][variable][thetype][category] = None
            
        
        # it's normal so it's a 1D.
    else: 
        temp = MnvH1D()
        temp = (f.Get(key))
        if (temp != 0): 
            print (sample,variable,thetype,category)
            if (category == "all"):
                print ("all", key)
            addentry(hists1D,sample,variable,thetype,category,temp.Clone())
            #hists1D[sample][variable][thetype][category].Scale(POTScale)
            #hists1D[sample][variable][thetype][category].Print()
            hists1D[sample][variable][thetype][category].SetDirectory(0)
            #print(" hist 1D " , sample , " " , variable , " " , thetype , " " , category , " " , hists1D[sample][variable][thetype][category].GetName() )
        #delete temp
        else: 
            #print("could not read " , key )
            hists1D[sample][variable][thetype][category] = None
    



# 2D hists

    if (hNd == "h2D" or "h2D" in key): 
        # partsof2D = split(variable, "_")
        hist = MnvH2D()
        hist = (f.Get(key))
        # Check if response is in its name
        if (hist != 0): 
            if ("migration" in key): 
                addentry(response2D,sample,variable,thetype,category,hist)
                response2D[sample][variable][thetype][category] = hist.Clone()
                #response2D[sample][variable][thetype][category].Print()
                #response2D[sample][variable][thetype][category].Scale(POTScale)
                response2D[sample][variable][thetype][category].SetDirectory(0)
                #print(" 2D migration " , sample , " " , variable , " " , thetype , " " , category )
                #delete hist
            else: 
                addentry(hists2D,sample,variable,thetype,category,hist)
                hists2D[sample][variable][thetype][category] = hist.Clone()
                #hists2D[sample][variable][thetype][category].Scale(POTScale)
                #hists2D[sample][variable][thetype][category].Print()
                hists2D[sample][variable][thetype][category].SetDirectory(0)
                #print(" hist 2D " , sample , " " , variable , " " , thetype , " " , category )
                #delete hist
            
    else: 
        #print("could not read " , key )
        if ("migration" in "key"): 
            addentry(response2D,sample,variable,thetype,category,0)
            #hists2D[sample][variable][thetype][category].Scale(POTScale)
            response2D[sample][variable][thetype][category] = None
        else: 
            addentry(hists2D,sample,variable,thetype,category,0)
            hists2D[sample][variable][thetype][category] = None
            

print (samples)
#print (hists1D)

keylist.close()
# Out:
#  add a sample:  1track
#  add a category:  data
#  add a variable:  Q2QE
#  add a thetype:  reconstructed
# 1track Q2QE reconstructed data
#  add a category:  1chargedpion
# 1track Q2QE reconstructed 1chargedpion
#  add a thetype:  selected_truth
# 1track Q2QE selected_truth 1chargedpion
#  add a thetype:  all_truth
# 1track Q2QE all_truth 1chargedpion
#  add a category:  1neutralpion
# 1track Q2QE reconstructed 1neutralpion
# 1track Q2QE selected_truth 1neutralpion
# 1track Q2QE all_truth 1neutralpion
#  add a category:  multipion
# 1track Q2QE reconstructed multipion
# 1track Q2QE selected_truth multipion
# 1track Q2QE all_truth multipion
#  add a category:  other
# 1track Q2QE reconstructed other
# 1track Q2QE selected_truth other
# 1track Q2QE all_truth other
#  add a category:  qelike
# 1track Q2QE reconstructed qelike
# 1track Q2QE selected_truth qelike
# 1track Q2QE all_truth qelike
#  add a thetype:  response_migration
# 1track Q2QE response_migration qelike
#  add a thetype:  response_reco
# 1track Q2QE response_reco qelike
#  add a thetype:  response_truth
# 1track Q2QE response_truth qelike
#  add a variable:  bdtg1ChargedPion
# 1track bdtg1ChargedPion reconstructed data
# 1track bdtg1ChargedPion reconstructed 1chargedpion
# 1track bdtg1ChargedPion selected_truth 1chargedpion
# 1track bdtg1ChargedPion all_truth 1chargedpion
# 1track bdtg1ChargedPion reconstructed 1neutralpion
# 1track bdtg1ChargedPion selected_truth 1neutralpion
# 1track bdtg1ChargedPion all_truth 1neutralpion
# 1track bdtg1ChargedPion reconstructed multipion
# 1track bdtg1ChargedPion selected_truth multipion
# 1track bdtg1ChargedPion all_truth multipion
# 1track bdtg1ChargedPion reconstructed other
# 1track bdtg1ChargedPion selected_truth other
# 1track bdtg1ChargedPion all_truth other
# 1track bdtg1ChargedPion reconstructed qelike
# 1track bdtg1ChargedPion selected_truth qelike
# 1track bdtg1ChargedPion all_truth qelike
# 1track bdtg1ChargedPion response_migration qelike
# 1track bdtg1ChargedPion response_reco qelike
# 1track bdtg1ChargedPion response_truth qelike
#  add a variable:  bdtg1NeutralPion
# 1track bdtg1NeutralPion reconstructed data
# 1track bdtg1NeutralPion reconstructed 1chargedpion
# 1track bdtg1NeutralPion selected_truth 1chargedpion
# 1track bdtg1NeutralPion all_truth 1chargedpion
# 1track bdtg1NeutralPion reconstructed 1neutralpion
# 1track bdtg1NeutralPion selected_truth 1neutralpion
# 1track bdtg1NeutralPion all_truth 1neutralpion
# 1track bdtg1NeutralPion reconstructed multipion
# 1track bdtg1NeutralPion selected_truth multipion
# 1track bdtg1NeutralPion all_truth multipion
# 1track bdtg1NeutralPion reconstructed other
# 1track bdtg1NeutralPion selected_truth other
# 1track bdtg1NeutralPion all_truth other
# 1track bdtg1NeutralPion reconstructed qelike
# 1track bdtg1NeutralPion selected_truth qelike
# 1track bdtg1NeutralPion all_truth qelike
# 1track bdtg1NeutralPion response_migration qelike
# 1track bdtg1NeutralPion response_reco qelike
# 1track bdtg1NeutralPion response_truth qelike
#  add a variable:  bdtgMultiPion
# 1track bdtgMultiPion reconstructed data
# 1track bdtgMultiPion reconstructed 1chargedpion
# 1track bdtgMultiPion selected_truth 1chargedpion
# 1track bdtgMultiPion all_truth 1chargedpion
# 1track bdtgMultiPion reconstructed 1neutralpion
# 1track bdtgMultiPion selected_truth 1neutralpion
# 1track bdtgMultiPion all_truth 1neutralpion
# 1track bdtgMultiPion reconstructed multipion
# 1track bdtgMultiPion selected_truth multipion
# 1track bdtgMultiPion all_truth multipion
# 1track bdtgMultiPion reconstructed other
# 1track bdtgMultiPion selected_truth other
# 1track bdtgMultiPion all_truth other
# 1track bdtgMultiPion reconstructed qelike
# 1track bdtgMultiPion selected_truth qelike
# 1track bdtgMultiPion all_truth qelike
# 1track bdtgMultiPion response_migration qelike
# 1track bdtgMultiPion response_reco qelike
# 1track bdtgMultiPion response_truth qelike
#  add a variable:  bdtgOther
# 1track bdtgOther reconstructed data
# 1track bdtgOther reconstructed 1chargedpion
# 1track bdtgOther selected_truth 1chargedpion
# 1track bdtgOther all_truth 1chargedpion
# 1track bdtgOther reconstructed 1neutralpion
# 1track bdtgOther selected_truth 1neutralpion
# 1track bdtgOther all_truth 1neutralpion
# 1track bdtgOther reconstructed multipion
# 1track bdtgOther selected_truth multipion
# 1track bdtgOther all_truth multipion
# 1track bdtgOther reconstructed other
# 1track bdtgOther selected_truth other
# 1track bdtgOther all_truth other
# 1track bdtgOther reconstructed qelike
# 1track bdtgOther selected_truth qelike
# 1track bdtgOther all_truth qelike
# 1track bdtgOther response_migration qelike
# 1track bdtgOther response_reco qelike
# 1track bdtgOther response_truth qelike
#  add a variable:  bdtgQELike
# 1track bdtgQELike reconstructed data
# 1track bdtgQELike reconstructed 1chargedpion
# 1track bdtgQELike selected_truth 1chargedpion
# 1track bdtgQELike all_truth 1chargedpion
# 1track bdtgQELike reconstructed 1neutralpion
# 1track bdtgQELike selected_truth 1neutralpion
# 1track bdtgQELike all_truth 1neutralpion
# 1track bdtgQELike reconstructed multipion
# 1track bdtgQELike selected_truth multipion
# 1track bdtgQELike all_truth multipion
# 1track bdtgQELike reconstructed other
# 1track bdtgQELike selected_truth other
# 1track bdtgQELike all_truth other
# 1track bdtgQELike reconstructed qelike
# 1track bdtgQELike selected_truth qelike
# 1track bdtgQELike all_truth qelike
# 1track bdtgQELike response_migration qelike
# 1track bdtgQELike response_reco qelike
# 1track bdtgQELike response_truth qelike
#  add a variable:  ptmu
# 1track ptmu reconstructed data
# 1track ptmu reconstructed 1chargedpion
# 1track ptmu selected_truth 1chargedpion
# 1track ptmu all_truth 1chargedpion
# 1track ptmu reconstructed 1neutralpion
# 1track ptmu selected_truth 1neutralpion
# 1track ptmu all_truth 1neutralpion
# 1track ptmu reconstructed multipion
# 1track ptmu selected_truth multipion
# 1track ptmu all_truth multipion
# 1track ptmu reconstructed other
# 1track ptmu selected_truth other
# 1track ptmu all_truth other
# 1track ptmu reconstructed qelike
# 1track ptmu selected_truth qelike
# 1track ptmu all_truth qelike
# 1track ptmu response_migration qelike
# 1track ptmu response_reco qelike
# 1track ptmu response_truth qelike
#  add a variable:  pzmu
# 1track pzmu reconstructed data
# 1track pzmu reconstructed 1chargedpion
# 1track pzmu selected_truth 1chargedpion
# 1track pzmu all_truth 1chargedpion
# 1track pzmu reconstructed 1neutralpion
# 1track pzmu selected_truth 1neutralpion
# 1track pzmu all_truth 1neutralpion
# 1track pzmu reconstructed multipion
# 1track pzmu selected_truth multipion
# 1track pzmu all_truth multipion
# 1track pzmu reconstructed other
# 1track pzmu selected_truth other
# 1track pzmu all_truth other
# 1track pzmu reconstructed qelike
# 1track pzmu selected_truth qelike
# 1track pzmu all_truth qelike
# 1track pzmu response_migration qelike
# 1track pzmu response_reco qelike
# 1track pzmu response_truth qelike
#  add a variable:  zvtx
# 1track zvtx reconstructed data
# 1track zvtx reconstructed 1chargedpion
# 1track zvtx selected_truth 1chargedpion
# 1track zvtx all_truth 1chargedpion
# 1track zvtx reconstructed 1neutralpion
# 1track zvtx selected_truth 1neutralpion
# 1track zvtx all_truth 1neutralpion
# 1track zvtx reconstructed multipion
# 1track zvtx selected_truth multipion
# 1track zvtx all_truth multipion
# 1track zvtx reconstructed other
# 1track zvtx selected_truth other
# 1track zvtx all_truth other
# 1track zvtx reconstructed qelike
# 1track zvtx selected_truth qelike
# 1track zvtx all_truth qelike
# 1track zvtx response_migration qelike
# 1track zvtx response_reco qelike
# 1track zvtx response_truth qelike
#  add a sample:  2track
# 2track Q2QE reconstructed data
# 2track Q2QE reconstructed 1chargedpion
# 2track Q2QE selected_truth 1chargedpion
# 2track Q2QE all_truth 1chargedpion
# 2track Q2QE reconstructed 1neutralpion
# 2track Q2QE selected_truth 1neutralpion
# 2track Q2QE all_truth 1neutralpion
# 2track Q2QE reconstructed multipion
# 2track Q2QE selected_truth multipion
# 2track Q2QE all_truth multipion
# 2track Q2QE reconstructed other
# 2track Q2QE selected_truth other
# 2track Q2QE all_truth other
# 2track Q2QE reconstructed qelike
# 2track Q2QE selected_truth qelike
# 2track Q2QE all_truth qelike
# 2track Q2QE response_migration qelike
# 2track Q2QE response_reco qelike
# 2track Q2QE response_truth qelike
# 2track bdtg1ChargedPion reconstructed data
# 2track bdtg1ChargedPion reconstructed 1chargedpion
# 2track bdtg1ChargedPion selected_truth 1chargedpion
# 2track bdtg1ChargedPion all_truth 1chargedpion
# 2track bdtg1ChargedPion reconstructed 1neutralpion
# 2track bdtg1ChargedPion selected_truth 1neutralpion
# 2track bdtg1ChargedPion all_truth 1neutralpion
# 2track bdtg1ChargedPion reconstructed multipion
# 2track bdtg1ChargedPion selected_truth multipion
# 2track bdtg1ChargedPion all_truth multipion
# 2track bdtg1ChargedPion reconstructed other
# 2track bdtg1ChargedPion selected_truth other
# 2track bdtg1ChargedPion all_truth other
# 2track bdtg1ChargedPion reconstructed qelike
# 2track bdtg1ChargedPion selected_truth qelike
# 2track bdtg1ChargedPion all_truth qelike
# 2track bdtg1ChargedPion response_migration qelike
# 2track bdtg1ChargedPion response_reco qelike
# 2track bdtg1ChargedPion response_truth qelike
# 2track bdtg1NeutralPion reconstructed data
# 2track bdtg1NeutralPion reconstructed 1chargedpion
# 2track bdtg1NeutralPion selected_truth 1chargedpion
# 2track bdtg1NeutralPion all_truth 1chargedpion
# 2track bdtg1NeutralPion reconstructed 1neutralpion
# 2track bdtg1NeutralPion selected_truth 1neutralpion
# 2track bdtg1NeutralPion all_truth 1neutralpion
# 2track bdtg1NeutralPion reconstructed multipion
# 2track bdtg1NeutralPion selected_truth multipion
# 2track bdtg1NeutralPion all_truth multipion
# 2track bdtg1NeutralPion reconstructed other
# 2track bdtg1NeutralPion selected_truth other
# 2track bdtg1NeutralPion all_truth other
# 2track bdtg1NeutralPion reconstructed qelike
# 2track bdtg1NeutralPion selected_truth qelike
# 2track bdtg1NeutralPion all_truth qelike
# 2track bdtg1NeutralPion response_migration qelike
# 2track bdtg1NeutralPion response_reco qelike
# 2track bdtg1NeutralPion response_truth qelike
# 2track bdtgMultiPion reconstructed data
# 2track bdtgMultiPion reconstructed 1chargedpion
# 2track bdtgMultiPion selected_truth 1chargedpion
# 2track bdtgMultiPion all_truth 1chargedpion
# 2track bdtgMultiPion reconstructed 1neutralpion
# 2track bdtgMultiPion selected_truth 1neutralpion
# 2track bdtgMultiPion all_truth 1neutralpion
# 2track bdtgMultiPion reconstructed multipion
# 2track bdtgMultiPion selected_truth multipion
# 2track bdtgMultiPion all_truth multipion
# 2track bdtgMultiPion reconstructed other
# 2track bdtgMultiPion selected_truth other
# 2track bdtgMultiPion all_truth other
# 2track bdtgMultiPion reconstructed qelike
# 2track bdtgMultiPion selected_truth qelike
# 2track bdtgMultiPion all_truth qelike
# 2track bdtgMultiPion response_migration qelike
# 2track bdtgMultiPion response_reco qelike
# 2track bdtgMultiPion response_truth qelike
# 2track bdtgOther reconstructed data
# 2track bdtgOther reconstructed 1chargedpion
# 2track bdtgOther selected_truth 1chargedpion
# 2track bdtgOther all_truth 1chargedpion
# 2track bdtgOther reconstructed 1neutralpion
# 2track bdtgOther selected_truth 1neutralpion
# 2track bdtgOther all_truth 1neutralpion
# 2track bdtgOther reconstructed multipion
# 2track bdtgOther selected_truth multipion
# 2track bdtgOther all_truth multipion
# 2track bdtgOther reconstructed other
# 2track bdtgOther selected_truth other
# 2track bdtgOther all_truth other
# 2track bdtgOther reconstructed qelike
# 2track bdtgOther selected_truth qelike
# 2track bdtgOther all_truth qelike
# 2track bdtgOther response_migration qelike
# 2track bdtgOther response_reco qelike
# 2track bdtgOther response_truth qelike
# 2track bdtgQELike reconstructed data
# 2track bdtgQELike reconstructed 1chargedpion
# 2track bdtgQELike selected_truth 1chargedpion
# 2track bdtgQELike all_truth 1chargedpion
# 2track bdtgQELike reconstructed 1neutralpion
# 2track bdtgQELike selected_truth 1neutralpion
# 2track bdtgQELike all_truth 1neutralpion
# 2track bdtgQELike reconstructed multipion
# 2track bdtgQELike selected_truth multipion
# 2track bdtgQELike all_truth multipion
# 2track bdtgQELike reconstructed other
# 2track bdtgQELike selected_truth other
# 2track bdtgQELike all_truth other
# 2track bdtgQELike reconstructed qelike
# 2track bdtgQELike selected_truth qelike
# 2track bdtgQELike all_truth qelike
# 2track bdtgQELike response_migration qelike
# 2track bdtgQELike response_reco qelike
# 2track bdtgQELike response_truth qelike
# 2track ptmu reconstructed data
# 2track ptmu reconstructed 1chargedpion
# 2track ptmu selected_truth 1chargedpion
# 2track ptmu all_truth 1chargedpion
# 2track ptmu reconstructed 1neutralpion
# 2track ptmu selected_truth 1neutralpion
# 2track ptmu all_truth 1neutralpion
# 2track ptmu reconstructed multipion
# 2track ptmu selected_truth multipion
# 2track ptmu all_truth multipion
# 2track ptmu reconstructed other
# 2track ptmu selected_truth other
# 2track ptmu all_truth other
# 2track ptmu reconstructed qelike
# 2track ptmu selected_truth qelike
# 2track ptmu all_truth qelike
# 2track ptmu response_migration qelike
# 2track ptmu response_reco qelike
# 2track ptmu response_truth qelike
# 2track pzmu reconstructed data
# 2track pzmu reconstructed 1chargedpion
# 2track pzmu selected_truth 1chargedpion
# 2track pzmu all_truth 1chargedpion
# 2track pzmu reconstructed 1neutralpion
# 2track pzmu selected_truth 1neutralpion
# 2track pzmu all_truth 1neutralpion
# 2track pzmu reconstructed multipion
# 2track pzmu selected_truth multipion
# 2track pzmu all_truth multipion
# 2track pzmu reconstructed other
# 2track pzmu selected_truth other
# 2track pzmu all_truth other
# 2track pzmu reconstructed qelike
# 2track pzmu selected_truth qelike
# 2track pzmu all_truth qelike
# 2track pzmu response_migration qelike
# 2track pzmu response_reco qelike
# 2track pzmu response_truth qelike
# 2track zvtx reconstructed data
# 2track zvtx reconstructed 1chargedpion
# 2track zvtx selected_truth 1chargedpion
# 2track zvtx all_truth 1chargedpion
# 2track zvtx reconstructed 1neutralpion
# 2track zvtx selected_truth 1neutralpion
# 2track zvtx all_truth 1neutralpion
# 2track zvtx reconstructed multipion
# 2track zvtx selected_truth multipion
# 2track zvtx all_truth multipion
# 2track zvtx reconstructed other
# 2track zvtx selected_truth other
# 2track zvtx all_truth other
# 2track zvtx reconstructed qelike
# 2track zvtx selected_truth qelike
# 2track zvtx all_truth qelike
# 2track zvtx response_migration qelike
# 2track zvtx response_reco qelike
# 2track zvtx response_truth qelike
#  add a sample:  3ptrack
# 3ptrack Q2QE reconstructed data
# 3ptrack Q2QE reconstructed 1chargedpion
# 3ptrack Q2QE selected_truth 1chargedpion
# 3ptrack Q2QE all_truth 1chargedpion
# 3ptrack Q2QE reconstructed 1neutralpion
# 3ptrack Q2QE selected_truth 1neutralpion
# 3ptrack Q2QE all_truth 1neutralpion
# 3ptrack Q2QE reconstructed multipion
# 3ptrack Q2QE selected_truth multipion
# 3ptrack Q2QE all_truth multipion
# 3ptrack Q2QE reconstructed other
# 3ptrack Q2QE selected_truth other
# 3ptrack Q2QE all_truth other
# 3ptrack Q2QE reconstructed qelike
# 3ptrack Q2QE selected_truth qelike
# 3ptrack Q2QE all_truth qelike
# 3ptrack Q2QE response_migration qelike
# 3ptrack Q2QE response_reco qelike
# 3ptrack Q2QE response_truth qelike
# 3ptrack bdtg1ChargedPion reconstructed data
# 3ptrack bdtg1ChargedPion reconstructed 1chargedpion
# 3ptrack bdtg1ChargedPion selected_truth 1chargedpion
# 3ptrack bdtg1ChargedPion all_truth 1chargedpion
# 3ptrack bdtg1ChargedPion reconstructed 1neutralpion
# 3ptrack bdtg1ChargedPion selected_truth 1neutralpion
# 3ptrack bdtg1ChargedPion all_truth 1neutralpion
# 3ptrack bdtg1ChargedPion reconstructed multipion
# 3ptrack bdtg1ChargedPion selected_truth multipion
# 3ptrack bdtg1ChargedPion all_truth multipion
# 3ptrack bdtg1ChargedPion reconstructed other
# 3ptrack bdtg1ChargedPion selected_truth other
# 3ptrack bdtg1ChargedPion all_truth other
# 3ptrack bdtg1ChargedPion reconstructed qelike
# 3ptrack bdtg1ChargedPion selected_truth qelike
# 3ptrack bdtg1ChargedPion all_truth qelike
# 3ptrack bdtg1ChargedPion response_migration qelike
# 3ptrack bdtg1ChargedPion response_reco qelike
# 3ptrack bdtg1ChargedPion response_truth qelike
# 3ptrack bdtg1NeutralPion reconstructed data
# 3ptrack bdtg1NeutralPion reconstructed 1chargedpion
# 3ptrack bdtg1NeutralPion selected_truth 1chargedpion
# 3ptrack bdtg1NeutralPion all_truth 1chargedpion
# 3ptrack bdtg1NeutralPion reconstructed 1neutralpion
# 3ptrack bdtg1NeutralPion selected_truth 1neutralpion
# 3ptrack bdtg1NeutralPion all_truth 1neutralpion
# 3ptrack bdtg1NeutralPion reconstructed multipion
# 3ptrack bdtg1NeutralPion selected_truth multipion
# 3ptrack bdtg1NeutralPion all_truth multipion
# 3ptrack bdtg1NeutralPion reconstructed other
# 3ptrack bdtg1NeutralPion selected_truth other
# 3ptrack bdtg1NeutralPion all_truth other
# 3ptrack bdtg1NeutralPion reconstructed qelike
# 3ptrack bdtg1NeutralPion selected_truth qelike
# 3ptrack bdtg1NeutralPion all_truth qelike
# 3ptrack bdtg1NeutralPion response_migration qelike
# 3ptrack bdtg1NeutralPion response_reco qelike
# 3ptrack bdtg1NeutralPion response_truth qelike
# 3ptrack bdtgMultiPion reconstructed data
# 3ptrack bdtgMultiPion reconstructed 1chargedpion
# 3ptrack bdtgMultiPion selected_truth 1chargedpion
# 3ptrack bdtgMultiPion all_truth 1chargedpion
# 3ptrack bdtgMultiPion reconstructed 1neutralpion
# 3ptrack bdtgMultiPion selected_truth 1neutralpion
# 3ptrack bdtgMultiPion all_truth 1neutralpion
# 3ptrack bdtgMultiPion reconstructed multipion
# 3ptrack bdtgMultiPion selected_truth multipion
# 3ptrack bdtgMultiPion all_truth multipion
# 3ptrack bdtgMultiPion reconstructed other
# 3ptrack bdtgMultiPion selected_truth other
# 3ptrack bdtgMultiPion all_truth other
# 3ptrack bdtgMultiPion reconstructed qelike
# 3ptrack bdtgMultiPion selected_truth qelike
# 3ptrack bdtgMultiPion all_truth qelike
# 3ptrack bdtgMultiPion response_migration qelike
# 3ptrack bdtgMultiPion response_reco qelike
# 3ptrack bdtgMultiPion response_truth qelike
# 3ptrack bdtgOther reconstructed data
# 3ptrack bdtgOther reconstructed 1chargedpion
# 3ptrack bdtgOther selected_truth 1chargedpion
# 3ptrack bdtgOther all_truth 1chargedpion
# 3ptrack bdtgOther reconstructed 1neutralpion
# 3ptrack bdtgOther selected_truth 1neutralpion
# 3ptrack bdtgOther all_truth 1neutralpion
# 3ptrack bdtgOther reconstructed multipion
# 3ptrack bdtgOther selected_truth multipion
# 3ptrack bdtgOther all_truth multipion
# 3ptrack bdtgOther reconstructed other
# 3ptrack bdtgOther selected_truth other
# 3ptrack bdtgOther all_truth other
# 3ptrack bdtgOther reconstructed qelike
# 3ptrack bdtgOther selected_truth qelike
# 3ptrack bdtgOther all_truth qelike
# 3ptrack bdtgOther response_migration qelike
# 3ptrack bdtgOther response_reco qelike
# 3ptrack bdtgOther response_truth qelike
# 3ptrack bdtgQELike reconstructed data
# 3ptrack bdtgQELike reconstructed 1chargedpion
# 3ptrack bdtgQELike selected_truth 1chargedpion
# 3ptrack bdtgQELike all_truth 1chargedpion
# 3ptrack bdtgQELike reconstructed 1neutralpion
# 3ptrack bdtgQELike selected_truth 1neutralpion
# 3ptrack bdtgQELike all_truth 1neutralpion
# 3ptrack bdtgQELike reconstructed multipion
# 3ptrack bdtgQELike selected_truth multipion
# 3ptrack bdtgQELike all_truth multipion
# 3ptrack bdtgQELike reconstructed other
# 3ptrack bdtgQELike selected_truth other
# 3ptrack bdtgQELike all_truth other
# 3ptrack bdtgQELike reconstructed qelike
# 3ptrack bdtgQELike selected_truth qelike
# 3ptrack bdtgQELike all_truth qelike
# 3ptrack bdtgQELike response_migration qelike
# 3ptrack bdtgQELike response_reco qelike
# 3ptrack bdtgQELike response_truth qelike
# 3ptrack ptmu reconstructed data
# 3ptrack ptmu reconstructed 1chargedpion
# 3ptrack ptmu selected_truth 1chargedpion
# 3ptrack ptmu all_truth 1chargedpion
# 3ptrack ptmu reconstructed 1neutralpion
# 3ptrack ptmu selected_truth 1neutralpion
# 3ptrack ptmu all_truth 1neutralpion
# 3ptrack ptmu reconstructed multipion
# 3ptrack ptmu selected_truth multipion
# 3ptrack ptmu all_truth multipion
# 3ptrack ptmu reconstructed other
# 3ptrack ptmu selected_truth other
# 3ptrack ptmu all_truth other
# 3ptrack ptmu reconstructed qelike
# 3ptrack ptmu selected_truth qelike
# 3ptrack ptmu all_truth qelike
# 3ptrack ptmu response_migration qelike
# 3ptrack ptmu response_reco qelike
# 3ptrack ptmu response_truth qelike
# 3ptrack pzmu reconstructed data
# 3ptrack pzmu reconstructed 1chargedpion
# 3ptrack pzmu selected_truth 1chargedpion
# 3ptrack pzmu all_truth 1chargedpion
# 3ptrack pzmu reconstructed 1neutralpion
# 3ptrack pzmu selected_truth 1neutralpion
# 3ptrack pzmu all_truth 1neutralpion
# 3ptrack pzmu reconstructed multipion
# 3ptrack pzmu selected_truth multipion
# 3ptrack pzmu all_truth multipion
# 3ptrack pzmu reconstructed other
# 3ptrack pzmu selected_truth other
# 3ptrack pzmu all_truth other
# 3ptrack pzmu reconstructed qelike
# 3ptrack pzmu selected_truth qelike
# 3ptrack pzmu all_truth qelike
# 3ptrack pzmu response_migration qelike
# 3ptrack pzmu response_reco qelike
# 3ptrack pzmu response_truth qelike
# 3ptrack zvtx reconstructed data
# 3ptrack zvtx reconstructed 1chargedpion
# 3ptrack zvtx selected_truth 1chargedpion
# 3ptrack zvtx all_truth 1chargedpion
# 3ptrack zvtx reconstructed 1neutralpion
# 3ptrack zvtx selected_truth 1neutralpion
# 3ptrack zvtx all_truth 1neutralpion
# 3ptrack zvtx reconstructed multipion
# 3ptrack zvtx selected_truth multipion
# 3ptrack zvtx all_truth multipion
# 3ptrack zvtx reconstructed other
# 3ptrack zvtx selected_truth other
# 3ptrack zvtx all_truth other
# 3ptrack zvtx reconstructed qelike
# 3ptrack zvtx selected_truth qelike
# 3ptrack zvtx all_truth qelike
# 3ptrack zvtx response_migration qelike
# 3ptrack zvtx response_reco qelike
# 3ptrack zvtx response_truth qelike
# added parameters
# added Covariance
# 5 5
# 0 0 4.5172140710511216e-05
# 0 1 -0.0002852782450863957
# 0 2 0.000805884124560945
# 0 3 2.0315427243730184e-06
# 0 4 -8.615506497010008e-05
# 1 0 -0.0002852782450863957
# 1 1 0.003939279917967803
# 1 2 -0.012562505114984478
# 1 3 -0.00017081009366845407
# 1 4 0.012071803635934745
# 2 0 0.000805884124560945
# 2 1 -0.012562505114984478
# 2 2 0.04453468859171347
# 2 3 0.0022277755249163057
# 2 4 -0.11803303185103595
# 3 0 2.0315427243730184e-06
# 3 1 -0.00017081009366845407
# 3 2 0.0022277755249163057
# 3 3 0.0013397286616788889
# 3 4 -0.054021063260259655
# 4 0 -8.615506497010008e-05
# 4 1 0.012071803635934745
# 4 2 -0.11803303185103595
# 4 3 -0.054021063260259655
# 4 4 2.268177245741394
#  add a thetype:  fitted
# 1track bdtgQELike fitted qelike
# 1track bdtgQELike fitted 1chargedpion
# 1track bdtgQELike fitted 1neutralpion
# 1track bdtgQELike fitted multipion
# 1track bdtgQELike fitted other
#  add a category:  all
# 1track bdtgQELike fitted all
# all h___1track___all___bdtgQELike___fitted
# 2track bdtgQELike fitted qelike
# 2track bdtgQELike fitted 1chargedpion
# 2track bdtgQELike fitted 1neutralpion
# 2track bdtgQELike fitted multipion
# 2track bdtgQELike fitted other
# 2track bdtgQELike fitted all
# all h___2track___all___bdtgQELike___fitted
# 1track bdtgQELike reconstructed all
# all h___1track___all___bdtgQELike___reconstructed
# 2track bdtgQELike reconstructed all
# all h___2track___all___bdtgQELike___reconstructed
#  add a category:  bkg
# 1track bdtgQELike fitted bkg
# 1track bdtgQELike fitted bkg
# 1track bdtgQELike fitted bkg
# 1track bdtgQELike fitted bkg
# 2track bdtgQELike fitted bkg
# 2track bdtgQELike fitted bkg
# 2track bdtgQELike fitted bkg
# 2track bdtgQELike fitted bkg
#  add a category:  bkgsub
# 1track bdtgQELike fitted bkgsub
# 2track bdtgQELike fitted bkgsub
# ['1track', '2track', '3ptrack']
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |1.27934
#    1 |0.971052
#    2 |2.2222
#    3 |1.13405
#    4 |3.67901
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 |  4.517e-05  -0.0002853   0.0008059   2.032e-06  -8.616e-05
#    1 | -0.0002853    0.003939    -0.01256  -0.0001708     0.01207
#    2 |  0.0008059    -0.01256     0.04453    0.002228      -0.118
#    3 |  2.032e-06  -0.0001708    0.002228     0.00134    -0.05402
#    4 | -8.616e-05     0.01207      -0.118    -0.05402       2.268

# %%
for sample in hists1D.keys():
    for variable in hists1D[sample].keys():
        for thetype in hists1D[sample][variable].keys():
            for category in hists1D[sample][variable][thetype].keys():
                if category in ["data","bkgsub"]: continue
                if hists1D[sample][variable][thetype][category] is not None:
                    hists1D[sample][variable][thetype][category].Scale(POTScale)
                # if hists2D[sample][variable][thetype][category] is not None:
                #     hists2D[sample][variable][thetype][category].Scale(POTScale)
                if thetype in ["response"]:
                    if response1D[sample][variable][thetype][category] is not None:
                        response1D[sample][variable][thetype][category].Scale(POTScale)
                    # if response2D[sample][variable][thetype][category] is not None:
                    #     response2D[sample][variable][thetype][category].Scale(POTScale)

# %%
g.cd()
# Out:
# True

# %%
# define the output file
#pdfname
#outroot
stune = "_untuned"
if (usetune): stune = "_tuned"
if (singlesample): 
    outname = inputname[:-5] + "_" +  stune + "_analyze"
    outroot = outname + ".root"

    # set up the outputs
    pdfname = outname
else: 
    outname = inputname[:-5] + stune + "_analyze"
    outroot = outname + ".root"

    # set up the outputs
    pdfname = outname  

o = TFile.Open(outroot, "RECREATE")
targetobj.Write()
#h_flux_dewidthed.Write()
pdffilename1D = pdfname + "_1D.pdf"
pdfstart1D = pdfname + "_1D.pdf("
pdfend1D = pdfname + "_1D.pdf)"

pdffilename1Dres = pdfname + "_1Dres.pdf"
pdfstart1Dres = pdfname + "_1Dres.pdf("
pdfend1Dres = pdfname + "_1Dres.pdf)"

pdffilename2D = pdfname + "_2D.pdf"
pdfstart2D = pdfname + "_2D.pdf("
pdfend2D = pdfname + "_2D.pdf)"

o.cd()
for s in hists1D: 
    sample = s 
    for v in hists1D[sample]: 
        variable = v 
        for t in hists1D[sample][variable]: 
            thetype = t 
            for c in hists1D[sample][variable][thetype]: 
                category = c 
                #print(" write out " , hists1D[sample][variable][thetype][category].GetName() )
                hists1D[sample][variable][thetype][category].Write()

# %%
print ("samples",samples)
print ("categories",categories)
print ("variables",variables)
print ("thetypes",thetypes)

print (hists1D)
# Out:
# samples ['1track', '2track', '3ptrack']
# categories ['data', '1chargedpion', '1neutralpion', 'multipion', 'other', 'qelike', 'all', 'bkg', 'bkgsub']
# variables ['Q2QE', 'bdtg1ChargedPion', 'bdtg1NeutralPion', 'bdtgMultiPion', 'bdtgOther', 'bdtgQELike', 'ptmu', 'pzmu', 'zvtx']
# thetypes ['reconstructed', 'selected_truth', 'all_truth', 'response_migration', 'response_reco', 'response_truth', 'fitted']
# {'1track': {'Q2QE': {'reconstructed': {'data': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9d3ac4a00>, '1chargedpion': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9c9eeaa00>, '1neutralpion': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9c62e4e00>, 'multipion': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9c7eca600>, 'other': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ba0a7800>, 'qelike': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9d4221400>}, 'selected_truth': {'1chargedpion': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9c62cf800>, '1neutralpion': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9c629fe00>, 'multipion': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ba09aa00>, 'other': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ba0aa600>, 'qelike': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9d4249600>}, 'all_truth': {'1chargedpion': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9c62e9a00>, '1neutralpion': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ba02f800>, 'multipion': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ba0a5000>, 'other': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9d4221a00>, 'qelike': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9d4249000>}, 'response_migration': {'qelike': <cppyy.gbl.PlotUtils.MnvH2D object at 0x7fa9ca232200>}, 'response_reco': {'qelike': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ba09c800>}, 'response_truth': {'qelike': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ca20ce00>}}, 'bdtg1ChargedPion': {'reconstructed': {'data': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ca229400>, '1chargedpion': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9d4243000>, '1neutralpion': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ba0ac200>, 'multipion': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9c62f8a00>, 'other': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ca23a000>, 'qelike': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ca23e800>}, 'selected_truth': {'1chargedpion': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ba09ea00>, '1neutralpion': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9d386f200>, 'multipion': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ca248c00>, 'other': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ca241800>, 'qelike': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ca253800>}, 'all_truth': {'1chargedpion': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ba09fc00>, '1neutralpion': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9d3ac3a00>, 'multipion': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ca243000>, 'other': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ca23d000>, 'qelike': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ca254a00>}, 'response_migration': {'qelike': <cppyy.gbl.PlotUtils.MnvH2D object at 0x7fa9ca273a00>}, 'response_reco': {'qelike': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ca259e00>}, 'response_truth': {'qelike': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ca24d800>}}, 'bdtg1NeutralPion': {'reconstructed': {'data': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ca24d200>, '1chargedpion': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ca26c800>, '1neutralpion': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ca287a00>, 'multipion': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ca28c800>, 'other': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9c62fa800>, 'qelike': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ca295e00>}, 'selected_truth': {'1chargedpion': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ca269e00>, '1neutralpion': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ca259000>, 'multipion': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ca28ec00>, 'other': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ca285600>, 'qelike': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ca298200>}, 'all_truth': {'1chargedpion': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ca26b600>, '1neutralpion': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ca28b000>, 'multipion': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9c62f9c00>, 'other': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ca294600>, 'qelike': <cppyy.gbl.PlotUtils.MnvH1D object at 0x7fa9ca29a600>}, 'response_migrati ...

# %%
for sample in samples:
    for variable in variables:
        for thetype in ["reconstructed"]:
            newtype = "reconstructed_scaled"
            for category in categoryMap.keys():
                if category == "data": continue
                index = categoryMap[category]
                hist = hists1D[sample][variable][thetype][category]
                print ("make rescaled version")
                #hist.Print()
                newname = hist.GetName().replace(thetype,newtype)
                newhist = scaleHist(hist,index, parameters,covariance,newname)
                #newhist.Print()
                newhist.Write()
                newhist.MnvH1DToCSV(newhist.GetName(),"./csv/",1.,False)
                addentry(hists1D,sample,variable,newtype,category,newhist)
                #hists1D[sample][variable][newtype][category].Print()
# Out:
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# make rescaled version
# uncertainty vectors
# TH1.Print Name  = h___1track___qelike___Q2QE___reconstructed, Entries= 349878, Total sum= 55902.8
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___1track___qelike___Q2QE___reconstructed_scaled, Entries= 349878, Total sum= 71518.6
# TH1.Print Name  = h___1track___1chargedpion___Q2QE___reconstructed, Entries= 263474, Total sum= 32490.6
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___1track___1chargedpion___Q2QE___reconstructed_scaled, Entries= 263474, Total sum= 31550.1
# TH1.Print Name  = h___1track___1neutralpion___Q2QE___reconstructed, Entries= 76487, Total sum= 9478.81
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___1track___1neutralpion___Q2QE___reconstructed_scaled, Entries= 76487, Total sum= 21063.9
# TH1.Print Name  = h___1track___multipion___Q2QE___reconstructed, Entries= 248175, Total sum= 41776.9
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___1track___multipion___Q2QE___reconstructed_scaled, Entries= 248175, Total sum= 47376.9
# TH1.Print Name  = h___1track___other___Q2QE___reconstructed, Entries= 7372, Total sum= 1242.1
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___1track___other___Q2QE___reconstructed_scaled, Entries= 7372, Total sum= 4569.68
# TH1.Print Name  = h___1track___qelike___bdtg1ChargedPion___reconstructed, Entries= 349878, Total sum= 56292.6
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___1track___qelike___bdtg1ChargedPion___reconstructed_scaled, Entries= 349878, Total sum= 72017.2
# TH1.Print Name  = h___1track___1chargedpion___bdtg1ChargedPion___reconstructed, Entries= 263474, Total sum= 33087.2
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___1track___1chargedpion___bdtg1ChargedPion___reconstructed_scaled, Entries= 263474, Total sum= 32129.4
# TH1.Print Name  = h___1track___1neutralpion___bdtg1ChargedPion___reconstructed, Entries= 76487, Total sum= 9703.76
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___1track___1neutralpion___bdtg1ChargedPion___reconstructed_scaled, Entries= 76487, Total sum= 21563.7
# TH1.Print Name  = h___1track___multipion___bdtg1ChargedPion___reconstructed, Entries= 248175, Total sum= 46148.2
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___1track___multipion___bdtg1ChargedPion___reconstructed_scaled, Entries= 248175, Total sum= 52334.2
# TH1.Print Name  = h___1track___other___bdtg1ChargedPion___reconstructed, Entries= 7372, Total sum= 1292.3
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___1track___other___bdtg1ChargedPion___reconstructed_scaled, Entries= 7372, Total sum= 4754.39
# TH1.Print Name  = h___1track___qelike___bdtg1NeutralPion___reconstructed, Entries= 349878, Total sum= 56292.6
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___1track___qelike___bdtg1NeutralPion___reconstructed_scaled, Entries= 349878, Total sum= 72017.2
# TH1.Print Name  = h___1track___1chargedpion___bdtg1NeutralPion___reconstructed, Entries= 263474, Total sum= 33087.2
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___1track___1chargedpion___bdtg1NeutralPion___reconstructed_scaled, Entries= 263474, Total sum= 32129.4
# TH1.Print Name  = h___1track___1neutralpion___bdtg1NeutralPion___reconstructed, Entries= 76487, Total sum= 9703.76
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___1track___1neutralpion___bdtg1NeutralPion___reconstructed_scaled, Entries= 76487, Total sum= 21563.7
# TH1.Print Name  = h___1track___multipion___bdtg1NeutralPion___reconstructed, Entries= 248175, Total sum= 46148.2
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___1track___multipion___bdtg1NeutralPion___reconstructed_scaled, Entries= 248175, Total sum= 52334.2
# TH1.Print Name  = h___1track___other___bdtg1NeutralPion___reconstructed, Entries= 7372, Total sum= 1292.3
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___1track___other___bdtg1NeutralPion___reconstructed_scaled, Entries= 7372, Total sum= 4754.39
# TH1.Print Name  = h___1track___qelike___bdtgMultiPion___reconstructed, Entries= 349878, Total sum= 56292.6
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___1track___qelike___bdtgMultiPion___reconstructed_scaled, Entries= 349878, Total sum= 72017.2
# TH1.Print Name  = h___1track___1chargedpion___bdtgMultiPion___reconstructed, Entries= 263474, Total sum= 33087.2
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___1track___1chargedpion___bdtgMultiPion___reconstructed_scaled, Entries= 263474, Total sum= 32129.4
# TH1.Print Name  = h___1track___1neutralpion___bdtgMultiPion___reconstructed, Entries= 76487, Total sum= 9703.76
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___1track___1neutralpion___bdtgMultiPion___reconstructed_scaled, Entries= 76487, Total sum= 21563.7
# TH1.Print Name  = h___1track___multipion___bdtgMultiPion___reconstructed, Entries= 248175, Total sum= 46148.2
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___1track___multipion___bdtgMultiPion___reconstructed_scaled, Entries= 248175, Total sum= 52334.2
# TH1.Print Name  = h___1track___other___bdtgMultiPion___reconstructed, Entries= 7372, Total sum= 1292.3
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___1track___other___bdtgMultiPion___reconstructed_scaled, Entries= 7372, Total sum= 4754.39
# TH1.Print Name  = h___1track___qelike___bdtgOther___reconstructed, Entries= 349878, Total sum= 56292.6
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___1track___qelike___bdtgOther___reconstructed_scaled, Entries= 349878, Total sum= 72017.2
# TH1.Print Name  = h___1track___1chargedpion___bdtgOther___reconstructed, Entries= 263474, Total sum= 33087.2
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___1track___1chargedpion___bdtgOther___reconstructed_scaled, Entries= 263474, Total sum= 32129.4
# TH1.Print Name  = h___1track___1neutralpion___bdtgOther___reconstructed, Entries= 76487, Total sum= 9703.76
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___1track___1neutralpion___bdtgOther___reconstructed_scaled, Entries= 76487, Total sum= 21563.7
# TH1.Print Name  = h___1track___multipion___bdtgOther___reconstructed, Entries= 248175, Total sum= 46148.2
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___1track___multipion___bdtgOther___reconstructed_scaled, Entries= 248175, Total sum= 52334.2
# TH1.Print Name  = h___1track___other___bdtgOther___reconstructed, Entries= 7372, Total sum= 1292.3
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___1track___other___bdtgOther___reconstructed_scaled, Entries= 7372, Total sum= 4754.39
# TH1.Print Name  = h___1track___qelike___bdtgQELike___reconstructed, Entries= 349878, Total sum= 56292.6
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___1track___qelike___bdtgQELike___reconstructed_scaled, Entries= 349878, Total sum= 72017.2
# TH1.Print Name  = h___1track___1chargedpion___bdtgQELike___reconstructed, Entries= 263474, Total sum= 33087.2
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___1track___1chargedpion___bdtgQELike___reconstructed_scaled, Entries= 263474, Total sum= 32129.4
# TH1.Print Name  = h___1track___1neutralpion___bdtgQELike___reconstructed, Entries= 76487, Total sum= 9703.76
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___1track___1neutralpion___bdtgQELike___reconstructed_scaled, Entries= 76487, Total sum= 21563.7
# TH1.Print Name  = h___1track___multipion___bdtgQELike___reconstructed, Entries= 248175, Total sum= 46148.2
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___1track___multipion___bdtgQELike___reconstructed_scaled, Entries= 248175, Total sum= 52334.2
# TH1.Print Name  = h___1track___other___bdtgQELike___reconstructed, Entries= 7372, Total sum= 1292.3
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___1track___other___bdtgQELike___reconstructed_scaled, Entries= 7372, Total sum= 4754.39
# TH1.Print Name  = h___1track___qelike___ptmu___reconstructed, Entries= 349878, Total sum= 56063.5
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
# ...
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___3ptrack___multipion___ptmu___reconstructed_scaled, Entries= 157857, Total sum= 32151.4
# TH1.Print Name  = h___3ptrack___other___ptmu___reconstructed, Entries= 4676, Total sum= 815.004
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___3ptrack___other___ptmu___reconstructed_scaled, Entries= 4676, Total sum= 2998.41
# TH1.Print Name  = h___3ptrack___qelike___pzmu___reconstructed, Entries= 10817, Total sum= 1561.53
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___3ptrack___qelike___pzmu___reconstructed_scaled, Entries= 10817, Total sum= 1997.72
# TH1.Print Name  = h___3ptrack___1chargedpion___pzmu___reconstructed, Entries= 45737, Total sum= 6365.7
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___3ptrack___1chargedpion___pzmu___reconstructed_scaled, Entries= 45737, Total sum= 6181.43
# TH1.Print Name  = h___3ptrack___1neutralpion___pzmu___reconstructed, Entries= 18135, Total sum= 2419.99
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___3ptrack___1neutralpion___pzmu___reconstructed_scaled, Entries= 18135, Total sum= 5377.71
# TH1.Print Name  = h___3ptrack___multipion___pzmu___reconstructed, Entries= 157857, Total sum= 26049.2
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___3ptrack___multipion___pzmu___reconstructed_scaled, Entries= 157857, Total sum= 29541
# TH1.Print Name  = h___3ptrack___other___pzmu___reconstructed, Entries= 4676, Total sum= 784.004
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___3ptrack___other___pzmu___reconstructed_scaled, Entries= 4676, Total sum= 2884.36
# TH1.Print Name  = h___3ptrack___qelike___zvtx___reconstructed, Entries= 10817, Total sum= 1623.5
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___3ptrack___qelike___zvtx___reconstructed_scaled, Entries= 10817, Total sum= 2077
# TH1.Print Name  = h___3ptrack___1chargedpion___zvtx___reconstructed, Entries= 45737, Total sum= 6671.82
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___3ptrack___1chargedpion___zvtx___reconstructed_scaled, Entries= 45737, Total sum= 6478.69
# TH1.Print Name  = h___3ptrack___1neutralpion___zvtx___reconstructed, Entries= 18135, Total sum= 2565.17
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___3ptrack___1neutralpion___zvtx___reconstructed_scaled, Entries= 18135, Total sum= 5700.32
# TH1.Print Name  = h___3ptrack___multipion___zvtx___reconstructed, Entries= 157857, Total sum= 29096.4
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___3ptrack___multipion___zvtx___reconstructed_scaled, Entries= 157857, Total sum= 32996.6
# TH1.Print Name  = h___3ptrack___other___zvtx___reconstructed, Entries= 4676, Total sum= 828.448
#
# Vector (5)  is as follows
#
#      |        1  |
# ------------------
#    0 |2.27578
#    1 |0.0420314
#    2 |0.000187262
#    3 |2.18276e-05
#    4 |1.4336e-05
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -5.724e-05    -0.02021      0.2153     -0.8692     -0.4447
#    1 |   0.005599      0.2979     -0.8479    0.007425     -0.4385
#    2 |   -0.05287     -0.9528     -0.2632     0.02797     -0.1387
#    3 |   -0.02376     0.01531      0.4068      0.4935     -0.7682
#    4 |     0.9983    -0.05177   0.0005152     0.01314     -0.0232
#
#
# 5x5 matrix is as follows
#
#      |      0    |      1    |      2    |      3    |      4    |
# ----------------------------------------------------------------------
#    0 | -8.635e-05    0.008446    -0.07975    -0.03585       1.506
#    1 |  -0.004143     0.06108     -0.1953    0.003138    -0.01061
#    2 |   0.002946     -0.0116   -0.003601    0.005567    7.05e-06
#    3 |  -0.004061   3.469e-05   0.0001307    0.002306   6.137e-05
#    4 |  -0.001684    -0.00166  -0.0005253   -0.002909  -8.784e-05
#
# TH1.Print Name  = h___3ptrack___other___zvtx___reconstructed_scaled, Entries= 4676, Total sum= 3047.87

# %%
mnvPlotter = MnvPlotter()
texname = os.path.basename(inputname.replace(".root",".tex"))
texfile = open(texname,'w')
texfile.write("\\input Header.tex\n")
cF = TCanvas()
for sample in samples:
    for variable in variables:
        for thetype in ["reconstructed","reconstructed_scaled"]:
            status = 1
            models = {}
            data = hists1D[sample][variable]["reconstructed"]["data"]
            typical = hists1D[sample][variable][thetype]["qelike"]
            total = MnvH1D()
            total = typical.Clone()
            total.SetName(data.GetName().replace("reconstructed",thetype).replace("data","tot"))
            total.Reset()
            bkg = MnvH1D()
            bkg = typical.Clone()
            bkg.SetName(data.GetName().replace("reconstructed",thetype).replace("data","bkg"))
            bkg.Reset()
            for category in categoryMap.keys():
                 models[category] = (hists1D[sample][variable][thetype][category])
                 if models[category] is None: 
                    print ("nothing here",sample,variable,thetype,category)
                    status = 0
                    break
                 total.Add(models[category],1.)
                 if category in allconfigs["Fit"]["Backgrounds"]:
                     bkg.Add(models[category],1.) 
            
            if status == 0: continue
            addentry(hists1D,sample,variable,thetype,"total",total)
            #print ("models",models)
            ModelArray = map2TObjArray(models)
            mnvPlotter.DrawDataStackedMC(data,ModelArray,1.0,"TR")
            cF.Print("pix/%s_%s_%s_%s"%(sample,variable,thetype,"stacked.png"))
            mnvPlotter.DrawDataMCRatio(data,total, 1. )
            cF.Print("pix/%s_%s_%s_%s"%(sample,variable,thetype,"ratio.png"))
            mnvPlotter.DrawDataMCWithErrorBand(data,total, 1., "TR");
            cF.Print("pix/%s_%s_%s_%s"%(sample,variable,thetype,"dataMC.png"))
            mnvPlotter.DrawErrorSummary(bkg);
            cF.Print("pix/%s_%s_%s_%s"%(sample,variable,thetype,"bkg_uncertainty.png"))

            s = TexFigure3(name1="pix/%s_%s_%s_%s"%(sample,variable,thetype,"stacked.png"), name2="pix/%s_%s_%s_%s"%(sample,variable,thetype,"ratio.png"),name3="pix/%s_%s_%s_%s"%(sample,variable,thetype,"dataMC.png"),
            name4="pix/%s_%s_%s_%s"%(sample,variable,thetype,"bkg_uncertainty.png"),caption="%s %s %s"%(sample,variable,thetype),label=None)
            
            texfile.write(s)
            bkg.Write()
            total.Write()
texfile.write("\\end{document}\n")
texfile.close()
# Out:
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# add to stack qelike qelike
# add to stack 1chargedpion 1chargedpion
# add to stack 1neutralpion 1neutralpion
# add to stack multipion multipion
# add to stack other other
# Info in <TCanvas::Print>: png file 1track_Q2QE_reconstructed_stacked.png has been created
# Info in <TCanvas::Print>: png file 1track_Q2QE_reconstructed_scaled_stacked.png has been created
# Info in <TCanvas::Print>: png file 1track_bdtg1ChargedPion_reconstructed_stacked.png has been created
# Info in <TCanvas::Print>: png file 1track_bdtg1ChargedPion_reconstructed_scaled_stacked.png has been created
# Info in <TCanvas::Print>: png file 1track_bdtg1NeutralPion_reconstructed_stacked.png has been created
# Info in <TCanvas::Print>: png file 1track_bdtg1NeutralPion_reconstructed_scaled_stacked.png has been created
# Info in <TCanvas::Print>: png file 1track_bdtgMultiPion_reconstructed_stacked.png has been created
# Info in <TCanvas::Print>: png file 1track_bdtgMultiPion_reconstructed_scaled_stacked.png has been created
# Info in <TCanvas::Print>: png file 1track_bdtgOther_reconstructed_stacked.png has been created
# Info in <TCanvas::Print>: png file 1track_bdtgOther_reconstructed_scaled_stacked.png has been created
# Info in <TCanvas::Print>: png file 1track_bdtgQELike_reconstructed_stacked.png has been created
# Info in <TCanvas::Print>: png file 1track_bdtgQELike_reconstructed_scaled_stacked.png has been created
# Info in <TCanvas::Print>: png file 1track_ptmu_reconstructed_stacked.png has been created
# Info in <TCanvas::Print>: png file 1track_ptmu_reconstructed_scaled_stacked.png has been created
# Info in <TCanvas::Print>: png file 1track_pzmu_reconstructed_stacked.png has been created
# Info in <TCanvas::Print>: png file 1track_pzmu_reconstructed_scaled_stacked.png has been created
# Info in <TCanvas::Print>: png file 1track_zvtx_reconstructed_stacked.png has been created
# Info in <TCanvas::Print>: png file 1track_zvtx_reconstructed_scaled_stacked.png has been created
# Info in <TCanvas::Print>: png file 2track_Q2QE_reconstructed_stacked.png has been created
# Info in <TCanvas::Print>: png file 2track_Q2QE_reconstructed_scaled_stacked.png has been created
# Info in <TCanvas::Print>: png file 2track_bdtg1ChargedPion_reconstructed_stacked.png has been created
# Info in <TCanvas::Print>: png file 2track_bdtg1ChargedPion_reconstructed_scaled_stacked.png has been created
# Info in <TCanvas::Print>: png file 2track_bdtg1NeutralPion_reconstructed_stacked.png has been created
# Info in <TCanvas::Print>: png file 2track_bdtg1NeutralPion_reconstructed_scaled_stacked.png has been created
# Info in <TCanvas::Print>: png file 2track_bdtgMultiPion_reconstructed_stacked.png has been created
# Info in <TCanvas::Print>: png file 2track_bdtgMultiPion_reconstructed_scaled_stacked.png has been created
# Info in <TCanvas::Print>: png file 2track_bdtgOther_reconstructed_stacked.png has been created
# Info in <TCanvas::Print>: png file 2track_bdtgOther_reconstructed_scaled_stacked.png has been created
# Info in <TCanvas::Print>: png file 2track_bdtgQELike_reconstructed_stacked.png has been created
# Info in <TCanvas::Print>: png file 2track_bdtgQELike_reconstructed_scaled_stacked.png has been created
# Info in <TCanvas::Print>: png file 2track_ptmu_reconstructed_stacked.png has been created
# Info in <TCanvas::Print>: png file 2track_ptmu_reconstructed_scaled_stacked.png has been created
# Info in <TCanvas::Print>: png file 2track_pzmu_reconstructed_stacked.png has been created
# Info in <TCanvas::Print>: png file 2track_pzmu_reconstructed_scaled_stacked.png has been created
# Info in <TCanvas::Print>: png file 2track_zvtx_reconstructed_stacked.png has been created
# Info in <TCanvas::Print>: png file 2track_zvtx_reconstructed_scaled_stacked.png has been created
# Info in <TCanvas::Print>: png file 3ptrack_Q2QE_reconstructed_stacked.png has been created
# Info in <TCanvas::Print>: png file 3ptrack_Q2QE_reconstructed_scaled_stacked.png has been created
# Info in <TCanvas::Print>: png file 3ptrack_bdtg1ChargedPion_reconstructed_stacked.png has been created
# Info in <TCanvas::Print>: png file 3ptrack_bdtg1ChargedPion_reconstructed_scaled_stacked.png has been created
# Info in <TCanvas::Print>: png file 3ptrack_bdtg1NeutralPion_reconstructed_stacked.png has been created
# Info in <TCanvas::Print>: png file 3ptrack_bdtg1NeutralPion_reconstructed_scaled_stacked.png has been created
# Info in <TCanvas::Print>: png file 3ptrack_bdtgMultiPion_reconstructed_stacked.png has been created
# Info in <TCanvas::Print>: png file 3ptrack_bdtgMultiPion_reconstructed_scaled_stacked.png has been created
# Info in <TCanvas::Print>: png file 3ptrack_bdtgOther_reconstructed_stacked.png has been created
# Info in <TCanvas::Print>: png file 3ptrack_bdtgOther_reconstructed_scaled_stacked.png has been created
# Info in <TCanvas::Print>: png file 3ptrack_bdtgQELike_reconstructed_stacked.png has been created
# Info in <TCanvas::Print>: png file 3ptrack_bdtgQELike_reconstructed_scaled_stacked.png has been created
# Info in <TCanvas::Print>: png file 3ptrack_ptmu_reconstructed_stacked.png has been created
# Info in <TCanvas::Print>: png file 3ptrack_ptmu_reconstructed_scaled_stacked.png has been created
# Info in <TCanvas::Print>: png file 3ptrack_pzmu_reconstructed_stacked.png has been created
# Info in <TCanvas::Print>: png file 3ptrack_pzmu_reconstructed_scaled_stacked.png has been created
# Info in <TCanvas::Print>: png file 3ptrack_zvtx_reconstructed_stacked.png has been created
# Info in <TCanvas::Print>: png file 3ptrack_zvtx_reconstructed_scaled_stacked.png has been created

# %%
for sample in samples:
    for variable in variables:
        if variable not in hists1D[sample].keys():
            print ("no variable in data for ",variable)
            continue
    
        print (sample,variable)
        
        tot = hists1D[sample][variable]["reconstructed"]["data"].Clone()
        
        totname =  tot.GetName().replace("data","tot")
        tot.Reset()
        tot.SetName(totname)
        for category in categories:  
            if category in ["all","bkg","bkgsub"]: 
                continue
            tmp = MnvH1D()
            tmp = hists1D[sample][variable]["reconstructed"][category].Clone()
            print ("tmp thetype",type(tmp))
            print (tmp.GetName())
            
            if not tmp: continue
            tot.Add(tmp,1.)
        addentry(hists1D,sample,variable,"reconstructed","tot",tmp)
        tmp.Write()
        tmp.Print()
# Out:
# 1track Q2QE
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___data___Q2QE___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___1chargedpion___Q2QE___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___1neutralpion___Q2QE___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___multipion___Q2QE___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___other___Q2QE___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___qelike___Q2QE___reconstructed
# 1track bdtg1ChargedPion
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___data___bdtg1ChargedPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___1chargedpion___bdtg1ChargedPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___1neutralpion___bdtg1ChargedPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___multipion___bdtg1ChargedPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___other___bdtg1ChargedPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___qelike___bdtg1ChargedPion___reconstructed
# 1track bdtg1NeutralPion
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___data___bdtg1NeutralPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___1chargedpion___bdtg1NeutralPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___1neutralpion___bdtg1NeutralPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___multipion___bdtg1NeutralPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___other___bdtg1NeutralPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___qelike___bdtg1NeutralPion___reconstructed
# 1track bdtgMultiPion
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___data___bdtgMultiPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___1chargedpion___bdtgMultiPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___1neutralpion___bdtgMultiPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___multipion___bdtgMultiPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___other___bdtgMultiPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___qelike___bdtgMultiPion___reconstructed
# 1track bdtgOther
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___data___bdtgOther___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___1chargedpion___bdtgOther___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___1neutralpion___bdtgOther___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___multipion___bdtgOther___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___other___bdtgOther___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___qelike___bdtgOther___reconstructed
# 1track bdtgQELike
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___data___bdtgQELike___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___1chargedpion___bdtgQELike___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___1neutralpion___bdtgQELike___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___multipion___bdtgQELike___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___other___bdtgQELike___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___qelike___bdtgQELike___reconstructed
# 1track ptmu
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___data___ptmu___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___1chargedpion___ptmu___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___1neutralpion___ptmu___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___multipion___ptmu___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___other___ptmu___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___qelike___ptmu___reconstructed
# 1track pzmu
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___data___pzmu___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___1chargedpion___pzmu___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___1neutralpion___pzmu___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___multipion___pzmu___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___other___pzmu___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___qelike___pzmu___reconstructed
# 1track zvtx
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___data___zvtx___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___1chargedpion___zvtx___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___1neutralpion___zvtx___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___multipion___zvtx___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___other___zvtx___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___1track___qelike___zvtx___reconstructed
# 2track Q2QE
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___data___Q2QE___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___1chargedpion___Q2QE___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___1neutralpion___Q2QE___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___multipion___Q2QE___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___other___Q2QE___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___qelike___Q2QE___reconstructed
# 2track bdtg1ChargedPion
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___data___bdtg1ChargedPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___1chargedpion___bdtg1ChargedPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___1neutralpion___bdtg1ChargedPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___multipion___bdtg1ChargedPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___other___bdtg1ChargedPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___qelike___bdtg1ChargedPion___reconstructed
# 2track bdtg1NeutralPion
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___data___bdtg1NeutralPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___1chargedpion___bdtg1NeutralPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___1neutralpion___bdtg1NeutralPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___multipion___bdtg1NeutralPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___other___bdtg1NeutralPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___qelike___bdtg1NeutralPion___reconstructed
# 2track bdtgMultiPion
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___data___bdtgMultiPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___1chargedpion___bdtgMultiPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___1neutralpion___bdtgMultiPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___multipion___bdtgMultiPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___other___bdtgMultiPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___qelike___bdtgMultiPion___reconstructed
# 2track bdtgOther
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___data___bdtgOther___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___1chargedpion___bdtgOther___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___1neutralpion___bdtgOther___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___multipion___bdtgOther___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___other___bdtgOther___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___qelike___bdtgOther___reconstructed
# 2track bdtgQELike
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___data___bdtgQELike___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___1chargedpion___bdtgQELike___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___1neutralpion___bdtgQELike___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___multipion___bdtgQELike___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___other___bdtgQELike___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___qelike___bdtgQELike___reconstructed
# 2track ptmu
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___data___ptmu___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___1chargedpion___ptmu___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___1neutralpion___ptmu___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___multipion___ptmu___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___other___ptmu___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___qelike___ptmu___reconstructed
# 2track pzmu
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___data___pzmu___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___1chargedpion___pzmu___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___1neutralpion___pzmu___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___multipion___pzmu___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___other___pzmu___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___qelike___pzmu___reconstructed
# 2track zvtx
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___data___zvtx___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___1chargedpion___zvtx___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___1neutralpion___zvtx___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___multipion___zvtx___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___other___zvtx___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___2track___qelike___zvtx___reconstructed
# 3ptrack Q2QE
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___data___Q2QE___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___1chargedpion___Q2QE___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___1neutralpion___Q2QE___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___multipion___Q2QE___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___other___Q2QE___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___qelike___Q2QE___reconstructed
# 3ptrack bdtg1ChargedPion
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___data___bdtg1ChargedPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___1chargedpion___bdtg1ChargedPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___1neutralpion___bdtg1ChargedPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___multipion___bdtg1ChargedPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___other___bdtg1ChargedPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___qelike___bdtg1ChargedPion___reconstructed
# 3ptrack bdtg1NeutralPion
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___data___bdtg1NeutralPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___1chargedpion___bdtg1NeutralPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___1neutralpion___bdtg1NeutralPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___multipion___bdtg1NeutralPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___other___bdtg1NeutralPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___qelike___bdtg1NeutralPion___reconstructed
# 3ptrack bdtgMultiPion
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___data___bdtgMultiPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___1chargedpion___bdtgMultiPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___1neutralpion___bdtgMultiPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___multipion___bdtgMultiPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___other___bdtgMultiPion___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___qelike___bdtgMultiPion___reconstructed
# 3ptrack bdtgOther
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___data___bdtgOther___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___1chargedpion___bdtgOther___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___1neutralpion___bdtgOther___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___multipion___bdtgOther___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___other___bdtgOther___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___qelike___bdtgOther___reconstructed
# 3ptrack bdtgQELike
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___data___bdtgQELike___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___1chargedpion___bdtgQELike___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___1neutralpion___bdtgQELike___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___multipion___bdtgQELike___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___other___bdtgQELike___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___qelike___bdtgQELike___reconstructed
# 3ptrack ptmu
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___data___ptmu___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___1chargedpion___ptmu___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___1neutralpion___ptmu___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___multipion___ptmu___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___other___ptmu___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___qelike___ptmu___reconstructed
# 3ptrack pzmu
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___data___pzmu___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___1chargedpion___pzmu___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___1neutralpion___pzmu___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___multipion___pzmu___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___other___pzmu___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___qelike___pzmu___reconstructed
# 3ptrack zvtx
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___data___zvtx___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___1chargedpion___zvtx___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___1neutralpion___zvtx___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___multipion___zvtx___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___other___zvtx___reconstructed
# tmp thetype <class cppyy.gbl.PlotUtils.MnvH1D at 0x7fa9d36ba310>
# h___3ptrack___qelike___zvtx___reconstructed
# TH1.Print Name  = h___1track___qelike___Q2QE___reconstructed, Entries= 349878, Total sum= 55902.8
# TH1.Print Name  = h___1track___qelike___bdtg1ChargedPion___reconstructed, Entries= 349878, Total sum= 56292.6
# TH1.Print Name  = h___1track___qelike___bdtg1NeutralPion___reconstructed, Entries= 349878, Total sum= 56292.6
# TH1.Print Name  = h___1track___qelike___bdtgMultiPion___reconstructed, Entries= 349878, Total sum= 56292.6
# TH1.Print Name  = h___1track___qelike___bdtgOther___reconstructed, Entries= 349878, Total sum= 56292.6
# TH1.Print Name  = h___1track___qelike___bdtgQELike___reconstructed, Entries= 349878, Total sum= 56292.6
# TH1.Print Name  = h___1track___qelike___ptmu___reconstructed, Entries= 349878, Total sum= 56063.5
# TH1.Print Name  = h___1track___qelike___pzmu___reconstructed, Entries= 349878, Total sum= 54711
# TH1.Print Name  = h___1track___qelike___zvtx___reconstructed, Entries= 349878, Total sum= 56292.6
# TH1.Print Name  = h___2track___qelike___Q2QE___reconstructed, Entries= 175052, Total sum= 30004.8
# TH1.Print Name  = h___2track___qelike___bdtg1ChargedPion___reconstructed, Entries= 175052, Total sum= 30343.3
# TH1.Print Name  = h___2track___qelike___bdtg1NeutralPion___reconstructed, Entries= 175052, Total sum= 30343.3
# TH1.Print Name  = h___2track___qelike___bdtgMultiPion___reconstructed, Entries= 175052, Total sum= 30343.3
# TH1.Print Name  = h___2track___qelike___bdtgOther___reconstructed, Entries= 175052, Total sum= 30343.3
# TH1.Print Name  = h___2track___qelike___bdtgQELike___reconstructed, Entries= 175052, Total sum= 30343.3
# TH1.Print Name  = h___2track___qelike___ptmu___reconstructed, Entries= 175052, Total sum= 30139.4
# TH1.Print Name  = h___2track___qelike___pzmu___reconstructed, Entries= 175052, Total sum= 29426.6
# TH1.Print Name  = h___2track___qelike___zvtx___reconstructed, Entries= 175052, Total sum= 30343.3
# TH1.Print Name  = h___3ptrack___qelike___Q2QE___reconstructed, Entries= 10817, Total sum= 1592.73
# TH1.Print Name  = h___3ptrack___qelike___bdtg1ChargedPion___reconstructed, Entries= 10817, Total sum= 1623.5
# TH1.Print Name  = h___3ptrack___qelike___bdtg1NeutralPion___reconstructed, Entries= 10817, Total sum= 1623.5
# TH1.Print Name  = h___3ptrack___qelike___bdtgMultiPion___reconstructed, Entries= 10817, Total sum= 1623.5
# TH1.Print Name  = h___3ptrack___qelike___bdtgOther___reconstructed, Entries= 10817, Total sum= 1623.5
# TH1.Print Name  = h___3ptrack___qelike___bdtgQELike___reconstructed, Entries= 10817, Total sum= 1623.5
# TH1.Print Name  = h___3ptrack___qelike___ptmu___reconstructed, Entries= 10817, Total sum= 1608.01
# TH1.Print Name  = h___3ptrack___qelike___pzmu___reconstructed, Entries= 10817, Total sum= 1561.53
# TH1.Print Name  = h___3ptrack___qelike___zvtx___reconstructed, Entries= 10817, Total sum= 1623.5

# %%
o.cd()
for name,config in allconfigs.items(): 
    print(" write out config " , name)
    obj = commentjson.dumps(config)
    object = TNamed()
    object = TNamed(name, obj)
    object.Write()
# Out:
#  write out config  main
#  write out config  varsFile
#  write out config  cutsFile
#  write out config  samplesFile
#  write out config  Fit

# %%
    
# Set up pdf for 1D plots.

canvas1D = TCanvas(pdffilename1D)
canvas1D.SetLeftMargin(0.15)
canvas1D.SetRightMargin(0.15)
canvas1D.SetBottomMargin(0.15)
canvas1D.SetTopMargin(0.15)
canvas1D.Print(pdfstart1D, "pdf")
# Out:
# Info in <TCanvas::Print>: pdf file /Users/schellma/Dropbox/FORGE/CCQENu/make_hists/BDT_3_out_tuned_analyze_1D.pdf has been created using the current canvas

# %%
#     # binwid = True  # flag you need if MnvPlotter does not do binwid correction.  If it does not, you need to set this to True

#     print(" just before 1D loop" )
#     for samples in hists1D: 
#         sample = samples.first
#         print(" Sample: " , sample )
#         for variables in hists1D[sample]:   # only do this for a subset to save output time.

#             variable = variables.first
#             if not checktag(AnalyzeVariables, variable):
#                 print(" don't do this variable for now" , variable )
#                 continue
            
#             print("  Variable: " , variable )
#             basename = "h_" + sample + "_" + variable
#             if (singlesample): 
#                 basename = "h_" + variable
            
#             print("basename is " , basename )
#             sys.exit = GetCrossSection(sample, variable, basename, hists1D[sample][variable], response1D[sample][variable], allconfigs, canvas1D, norm, POTScale, h_flux_dewidthed, unfold, num_iter, DEBUG, hasbkgsub, usetune, pdfname)

#             if (DEBUG): print(sys.exit )
        
    
#     print(" end of 1D loop" )
#     # Close pdf for 1D plots.
#     canvas1D.Print(pdfend1D, "pdf")

#     canvas1Dres = TCanvas(pdffilename1Dres)
#     canvas1Dres.SetLeftMargin(0.15)
#     canvas1Dres.SetRightMargin(0.15)
#     canvas1Dres.SetBottomMargin(0.15)
#     canvas1Dres.SetTopMargin(0.15)
#     canvas1Dres.Print(pdfstart1Dres, "pdf")
#     # # resolutions = ("resolution"), ("tuned_resolution")

#     for samples in hists1D: 
#         sample = samples.first
#         print(" Sample: " , sample )
#         for variables in hists1D[sample]:   # only do this for a subset to save output time.

#             variable = variables.first
#             if "_resolution" in variable: continue
#             #if (variable.find("_resolution"): == std.string.npos): continue

#             for t in hists1D[sample][variable]: 
#                 resthetype = t.first
#                 print("resthetype " , resthetype )
#                 for c in hists1D[sample][variable][resthetype]: 
#                     category = c.first
#                     h = MnvH1D()
#                     h = hists1D[sample][variable][resthetype][category].Clone()
#                     if (h.GetEntries() == 0): continue
#                     label = ("resolution_")+sample+"_"+variable+"_"+resthetype+"_"+category
#                     PlotCVAndError(canvas1Dres, h, h, label, False, 0, True)
                
            
        
    

#     canvas1Dres.Print(pdfend1Dres, "pdf")

#     # Set up pdf for 2D plots.
#     canvas2D = TCanvas(pdffilename2D)
#     canvas2D.SetLeftMargin(0.15)
#     canvas2D.SetRightMargin(0.15)
#     canvas2D.SetBottomMargin(0.15)
#     canvas2D.SetTopMargin(0.15)
#     canvas2D.Print(pdfstart2D, "pdf")

#     print(" just before 2D loop" )
#     for samples in hists2D: 
#         sample = samples.first

#         for variables in hists2D[sample]:   # only do this for a subset to save output time.
#             variable = variables.first
#             if not checktag(AnalyzeVariables2D, variable):
#                 print(" don't do this variable for now" , variable )
#                 continue
            
#             basename = "h2D_" + sample + "_" + variable
#             if (singlesample): 
#                 basename = "h_" + variable
            
#             sys.exit = GetCrossSection(sample, variable, basename, hists2D[sample][variable], response2D[sample][variable], allconfigs, canvas2D, norm, POTScale, h_flux_dewidthed, unfold, num_iter, DEBUG, hasbkgsub, usetune, pdfname)
#             if (DEBUG): print(sys.exit )
        
    
#     print(" end of 2D loop" )
#     canvas2D.Print(pdfend2D, "pdf")
#     # Close pdf for 2D plots.

#     o.close()
#     sys.exit(0)

# if len(sys.argv) < 2:
#     print ("give me a root file to chew on")
# else:
#     main()
